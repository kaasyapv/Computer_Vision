# %% [markdown]
# <a href="https://colab.research.google.com/github/kaasyapv/Computer_Vision/blob/main/QR_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode[pil] --quiet

import qrcode

students = ["Sam"]

for name in students:
    img = qrcode.make(name)
    img.save(f"{name}.png")
    print(f"Generated QR for {name}")
# Out:
# Generated QR for Sam
